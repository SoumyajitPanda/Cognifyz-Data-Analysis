# %% [markdown]
# Task: Geographic Analysis

# %%
import pandas as pd
import folium

# %%
# Load Dataset
df = pd.read_csv("../Dataset .csv")

# %%
# Remove missing coordinates
df = df.dropna(subset=["Latitude", "Longitude"])

# %%
# Create Map
restaurant_map = folium.Map(
    location=[df["Latitude"].mean(),
              df["Longitude"].mean()],
    zoom_start=5
)

# %%
# Add first 200 restaurants
for _, row in df.head(200).iterrows():

    folium.Marker(
        location=[row["Latitude"],
                  row["Longitude"]],
        popup=row["Restaurant Name"]
    ).add_to(restaurant_map)

# %%
# Save Map
restaurant_map.save("Restaurant_Map.html")

# Display Map
restaurant_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1c84d1560f0ae844f5a2a3c3a83fbb2e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1c84d1560f0ae844f5a2a3c3a83fbb2e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1c84d1560f0ae844f5a2a3c3a83fbb2e = L.map(
#                 &quot;map_1c84d1560f0ae844f5a2a3c3a83fbb2e&quot;,
#                 {
#                     center: [25.854380700074756, 64.12657446168704],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_26b198de35541a787318a1f76a449389 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_26b198de35541a787318a1f76a449389.addTo(map_1c84d1560f0ae844f5a2a3c3a83fbb2e);
#
#
#             var marker_85b0e0b362b2dd964bfb3f87cb2d10f0 = L.marker(
#                 [14.565443, 121.027535],
#                 {
# }
#             ).addTo(map_1c84d1560f0ae844f5a2a3c3a83fbb2e);
#
#
#         var popup_8e8d9d9db001651ca83d119ada6139e3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4890cfb7904d884cd7fa93443a7b0f2d = $(`&lt;div id=&quot;html_4890cfb7904d884cd7fa93443a7b0f2d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Le Petit Souffle&lt;/div&gt;`)[0];
#                 popup_8e8d9d9db001651ca83d119ada6139e3.setContent(html_4890cfb7904d884cd7fa93443a7b0f2d);
#
#
#
#         marker_85b0e0b362b2dd964bfb3f87cb2d10f0.bindPopup(popup_8e8d9d9db001651ca83d119ada6139e3)
#         ;
#
#
#
#
#             var marker_e7eba21f1afa46e44464de2a403a4b05 = L.marker(
#                 [14.553708, 121.014101],
#                 {
# }
#             ).addTo(map_1c84d1560f0ae844f5a2a3c3a83fbb2e);
#
#
#         var popup_8ccbf7c9f23d4f24fc8fa15625edc8c2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c052c2b7bc904dcf6e89eeb6bd819fa6 = $(`&lt;div id=&quot;html_c052c2b7bc904dcf6e89eeb6bd819fa6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Izakaya Kikufuji&lt;/div&gt;`)[0];
#                 popup_8ccbf7c9f23d4f24fc8fa15625edc8c2.setContent(html_c052c2b7bc904dcf6e89eeb6bd819fa6);
#
#
#
#         marker_e7eba21f1afa46e44464de2a403a4b05.bindPopup(popup_8ccbf7c9f23d4f24fc8fa15625edc8c2)
#         ;
#
#
#
#
#             var marker_bb196625a0fa620a640b603f9720aebe = L.marker(
#                 [14.581404, 121.056831],
#                 {
# }
#             ).addTo(map_1c84d1560f0ae844f5a2a3c3a83fbb2e);
#
#
#         var popup_7a7a2745009773b6c4b773d04f3c4198 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_745a8d0b44df18a00640ce4ad3a9d1ba = $(`&lt;div id=&quot;html_745a8d0b44df18a00640ce4ad3a9d1ba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Heat - Edsa Shangri-La&lt;/div&gt;`)[0];
#                 popup_7a7a2745009773b6c4b773d04f3c4198.setContent(html_745a8d0b44df18a00640ce4ad3a9d1ba);
#
#
#
#         marker_bb196625a0fa620a640b603f9720aebe.bindPopup(popup_7a7a2745009773b6c4b773d04f3c4198)
#         ;
#
#
#
#
#             var marker_7e8a479004808cdbbecac046c23581d9 = L.marker(
#                 [14.585318, 121.056475],
#                 {
# }
#             ).addTo(map_1c84d1560f0ae844f5a2a3c3a83fbb2e);
#
#
#         var popup_93a2445f85b71dfa40bde40922735423 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e67121275a43a8d5786bc03c4e1f88e5 = $(`&lt;div id=&quot;html_e67121275a43a8d5786bc03c4e1f88e5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Ooma&lt;/div&gt;`)[0];
#                 popup_93a2445f85b71dfa40bde40922735423.setContent(html_e67121275a43a8d5786bc03c4e1f88e5);
#
#
#
#         marker_7e8a479004808cdbbecac046c23581d9.bindPopup(popup_93a2445f85b71dfa40bde40922735423)
#         ;
#
#
#
#
#             var marker_6e592738709577c0fbdc41fa5931f99e = L.marker(
#                 [14.58445, 121.057508],
#                 {
# }
#             ).addTo(map_1c84d1560f0ae844f5a2a3c3a83fbb2e);
#
#
#         var popup_3c48944b3460464cfe1d7fc34cb3d33b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4dc780064dc729300f39b25561a1a8cb = $(`&lt;div id=&quot;html_4dc780064dc729300f39b25561a1a8cb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sambo Kojin&lt;/div&gt;`)[0];
#                 popup_3c48944b3460464cfe1d7fc34cb3d33b.setContent(html_4dc780064dc729300f39b25561a1a8cb);

# %%
# City Analysis
city_count = df["City"].value_counts()

print(city_count.head(10))
# Out:
# City
# New Delhi       5473
# Gurgaon         1118
# Noida           1080
# Faridabad        251
# Ghaziabad         25
# Ahmedabad         21
# Amritsar          21
# Bhubaneshwar      21
# Guwahati          21
# Lucknow           21
# Name: count, dtype: int64
